# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telco= pd.read_csv("Custdetails.csv")

# %%
telco.head()
# Out:
#   customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 0  0002-ORFBO  Female       True                  0     Yes        Yes
# 1  0003-MKNFE    Male      False                  0      No         No
# 2  0004-TLHLJ    Male      False                  0      No         No
# 3  0011-IGKFF    Male      False                  1     Yes         No
# 4  0013-EXCHZ  Female       True                  1     Yes         No
#
#    phone_service  has_phone  internet_service  has_internet  ...  \
# 0              1       True                 1          True  ...
# 1              2       True                 1          True  ...
# 2              1       True                 2          True  ...
# 3              1       True                 2          True  ...
# 4              1       True                 2          True  ...
#
#    contract_type      payment_type monthly_charges  total_charges  churn  \
# ...

# %%
telco= telco.drop(columns=["payment_type",'gender', 'is_senior_citizen', "partner", "dependents","partner_dependents","payment_type","is_female","average_monthly_charges"])
